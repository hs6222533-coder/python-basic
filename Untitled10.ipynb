# %%
import pandas as pd

data = pd.DataFrame({
    'Customer_ID': [101, 102, 103, 104, 105, 106, 107, 108],
    'Customer_Name': [
        'aarav sharma ',
        'RIYA VERMA',
        'neha singh',
        'Rahul Kumar',
        'Priya MEHTA ',
        'aman joshi',
        'Karan Sharma',
        'sneha gupta '
    ],
    'City': [
        'jaipur', 'Delhi ', ' MUMBAI', 'Jaipur',
        'delhi', 'Mumbai ', 'JODHPUR', ' jaipur '
    ],
    'Product': [
        'Smartphone',
        'Laptop',
        'Phone Case',
        'Shoes',
        'Smart Watch',
        'Tablet',
        'Speaker',
        'Mobile Phone'
    ],
    'Email': [
        'aarav@gmail.com',
        'riya@yahoo.com',
        'neha@gmail.com',
        'rahul@outlook.com',
        'priya@gmail.com',
        'aman@yahoo.com',
        'karan@gmail.com',
        'sneha@outlook.com'
    ]
})

df = pd.DataFrame(data)
print(df)
# Out:
#    Customer_ID  Customer_Name      City       Product              Email
# 0          101  aarav sharma     jaipur    Smartphone    aarav@gmail.com
# 1          102     RIYA VERMA    Delhi         Laptop     riya@yahoo.com
# 2          103     neha singh    MUMBAI    Phone Case     neha@gmail.com
# 3          104    Rahul Kumar    Jaipur         Shoes  rahul@outlook.com
# 4          105   Priya MEHTA      delhi   Smart Watch    priya@gmail.com
# 5          106     aman joshi   Mumbai         Tablet     aman@yahoo.com
# 6          107   Karan Sharma   JODHPUR       Speaker    karan@gmail.com
# 7          108   sneha gupta    jaipur   Mobile Phone  sneha@outlook.com

# %%
df['Customer_Name'] = df["Customer_Name"].str.upper()
df['Customer_Name']
# Out:
# 0     AARAV SHARMA
# 1        RIYA VERMA
# 2        NEHA SINGH
# 3       RAHUL KUMAR
# 4      PRIYA MEHTA
# 5        AMAN JOSHI
# 6      KARAN SHARMA
# 7      SNEHA GUPTA
# Name: Customer_Name, dtype: object

# %%
df['Customer_Name'] = df["Customer_Name"].str.lower()
df['Customer_Name']
# Out:
# 0     aarav sharma
# 1        riya verma
# 2        neha singh
# 3       rahul kumar
# 4      priya mehta
# 5        aman joshi
# 6      karan sharma
# 7      sneha gupta
# Name: Customer_Name, dtype: object

# %%
df['Customer_Name'] = df["Customer_Name"].str.strip()
df['Customer_Name']
# Out:
# 0    aarav sharma
# 1      riya verma
# 2      neha singh
# 3     rahul kumar
# 4     priya mehta
# 5      aman joshi
# 6    karan sharma
# 7     sneha gupta
# Name: Customer_Name, dtype: object

# %%
df['Customer_Name'] = df["Customer_Name"].str.len()
df['Customer_Name']
# Out:
# 0    12
# 1    10
# 2    10
# 3    11
# 4    11
# 5    10
# 6    12
# 7    11
# Name: Customer_Name, dtype: int64

# %%
df[df["Product"].str.contains("phone",case=False,na=False)]
# Out:
#    Customer_ID  Customer_Name      City       Product              Email
# 0          101             12    jaipur    Smartphone    aarav@gmail.com
# 2          103             10    MUMBAI    Phone Case     neha@gmail.com
# 7          108             11   jaipur   Mobile Phone  sneha@outlook.com

# %%
df[df["Customer_Name"].str.startswith("a",na=False)]
# Out:
#    Customer_ID  Customer_Name     City     Product            Email
# 0          101  aarav sharma    jaipur  Smartphone  aarav@gmail.com
# 5          106     aman joshi  Mumbai       Tablet   aman@yahoo.com

# %%
df[df["Product"].str.endswith("e")]
# Out:
#    Customer_ID   Customer_Name      City       Product              Email
# 0          101   aarav sharma     jaipur    Smartphone    aarav@gmail.com
# 2          103      neha singh    MUMBAI    Phone Case     neha@gmail.com
# 7          108    sneha gupta    jaipur   Mobile Phone  sneha@outlook.com

# %%
df["Product"].str.replace("Phone Case","PhoneCase")
# Out:
# 0      Smartphone
# 1          Laptop
# 2       PhoneCase
# 3           Shoes
# 4     Smart Watch
# 5          Tablet
# 6         Speaker
# 7    Mobile Phone
# Name: Product, dtype: object

# %%
df["Customer_Name"].str[0]
# Out:
# 0    a
# 1    R
# 2    n
# 3    R
# 4    P
# 5    a
# 6    K
# 7    s
# Name: Customer_Name, dtype: object

# %%
df["Customer_Name"].str.split().str[0]
# Out:
# 0    aarav
# 1     RIYA
# 2     neha
# 3    Rahul
# 4    Priya
# 5     aman
# 6    Karan
# 7    sneha
# Name: Customer_Name, dtype: object

# %%
df["Customer_Name"].str.split().str[-1]
# Out:
# 0    sharma
# 1     VERMA
# 2     singh
# 3     Kumar
# 4     MEHTA
# 5     joshi
# 6    Sharma
# 7     gupta
# Name: Customer_Name, dtype: object

# %%
df["Email"].str.split("@").str[1]
# Out:
# 0      gmail.com
# 1      yahoo.com
# 2      gmail.com
# 3    outlook.com
# 4      gmail.com
# 5      yahoo.com
# 6      gmail.com
# 7    outlook.com
# Name: Email, dtype: object

# %%
df["Email"].str.split("@").str[0]
# Out:
# 0    aarav
# 1     riya
# 2     neha
# 3    rahul
# 4    priya
# 5     aman
# 6    karan
# 7    sneha
# Name: Email, dtype: object

# %%
df[df["Email"].str.endswith("gmail.com")]
# Out:
#    Customer_ID  Customer_Name     City      Product            Email
# 0          101  aarav sharma    jaipur   Smartphone  aarav@gmail.com
# 2          103     neha singh   MUMBAI   Phone Case   neha@gmail.com
# 4          105   Priya MEHTA     delhi  Smart Watch  priya@gmail.com
# 6          107   Karan Sharma  JODHPUR      Speaker  karan@gmail.com

# %%
df["Customer_Name"].str.strip().str.title()
# Out:
# 0    Aarav Sharma
# 1      Riya Verma
# 2      Neha Singh
# 3     Rahul Kumar
# 4     Priya Mehta
# 5      Aman Joshi
# 6    Karan Sharma
# 7     Sneha Gupta
# Name: Customer_Name, dtype: object

# %%
df["City"].str.strip().str.title()
# Out:
# 0     Jaipur
# 1      Delhi
# 2     Mumbai
# 3     Jaipur
# 4      Delhi
# 5     Mumbai
# 6    Jodhpur
# 7     Jaipur
# Name: City, dtype: object

# %%
df[df["Customer_Name"].str.contains("sharma", case=False)]
# Out:
#    Customer_ID  Customer_Name     City     Product            Email
# 0          101  aarav sharma    jaipur  Smartphone  aarav@gmail.com
# 6          107   Karan Sharma  JODHPUR     Speaker  karan@gmail.com

# %%
df[df["Product"].str.contains("phone|smart", case=False)]
# Out:
#    Customer_ID  Customer_Name      City       Product              Email  \
# 0          101  aarav sharma     jaipur    Smartphone    aarav@gmail.com
# 2          103     neha singh    MUMBAI    Phone Case     neha@gmail.com
# 4          105   Priya MEHTA      delhi   Smart Watch    priya@gmail.com
# 7          108   sneha gupta    jaipur   Mobile Phone  sneha@outlook.com
#
#   First_Name Last_Name
# 0      aarav    sharma
# 2       neha     singh
# 4      Priya     MEHTA
# 7      sneha     gupta

# %%
df["Customer_Name"].str.split().str.len()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# 5    2
# 6    2
# 7    2
# Name: Customer_Name, dtype: int64

# %%
df['First_Name'] = df['Customer_Name'].str.split().str[0]
df['Last_Name'] = df['Customer_Name'].str.split().str[1]
print(df)
# Out:
#    Customer_ID Customer_Name      City       Product              Email  \
# 0          101  aarav sharma    jaipur    Smartphone    aarav@gmail.com
# 1          102    RIYA VERMA    Delhi         Laptop     riya@yahoo.com
# 2          103    neha singh    MUMBAI    Phone Case     neha@gmail.com
# 3          104   Rahul Kumar    Jaipur         Shoes  rahul@outlook.com
# 4          105   Priya MEHTA     delhi   Smart Watch    priya@gmail.com
# 5          106    aman joshi   Mumbai         Tablet     aman@yahoo.com
# 6          107  Karan Sharma   JODHPUR       Speaker    karan@gmail.com
# 7          108   sneha gupta   jaipur   Mobile Phone  sneha@outlook.com
#
#   First_Name Last_Name
# 0      aarav    sharma
# 1       RIYA     VERMA
# 2       neha     singh
# 3      Rahul     Kumar
# 4      Priya     MEHTA
# 5       aman     joshi
# 6      Karan    Sharma
# 7      sneha     gupta
