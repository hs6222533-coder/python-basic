# %%
import pandas as pd

# %%
data = {
    "Emp_ID": ["E101","E102","E103","E104","E105","E106","E107","E108","E109","E110","E111","E112"],
    "Employee": ["Aman","Riya","Neha","Rahul","Priya","Karan","Sneha","Vikas","Anjali","Mohit","Pooja","Arjun"],
    "Department": ["Sales","HR","IT","Sales","Finance","IT","HR","Sales","Finance","IT","Sales","HR"],
    "City": ["Jaipur","Delhi","Mumbai","Jaipur","Pune","Delhi","Mumbai","Pune","Delhi","Jaipur","Mumbai","Pune"],
    "Salary": [42000,52000,68000,47000,61000,75000,55000,49000,72000,65000,58000,45000],
    "Experience": [2,4,6,3,5,7,4,3,6,5,4,2],
    "Sales": [85000,72000,125000,91000,115000,138000,79000,102000,132000,119000,97000,68000],
    "Rating": [3.8,4.2,4.7,3.9,4.5,4.8,4.1,3.7,4.6,4.4,4.0,3.5]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8
# 1    E102     Riya         HR   Delhi   52000           4   72000     4.2
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5

# %%
df.sort_values(by="Salary", ascending=False)
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 1    E102     Riya         HR   Delhi   52000           4   72000     4.2
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8

# %%
df.sort_values(by=["Department", "Salary"],ascending=[True, False])
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 1    E102     Riya         HR   Delhi   52000           4   72000     4.2
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8

# %%
df.sort_values(by="Sales", ascending=False).head(5)
# Out:
#   Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 5   E106    Karan         IT   Delhi   75000           7  138000     4.8
# 8   E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 2   E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 9   E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 4   E105    Priya    Finance    Pune   61000           5  115000     4.5

# %%
df.sort_values(by=["Rating", "Experience"],ascending=[False, True])
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 1    E102     Riya         HR   Delhi   52000           4   72000     4.2
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5

# %%
df.sort_values(by=["City", "Sales"], ascending=[True, False])[["Employee", "City", "Sales"]]
# Out:
#    Employee    City   Sales
# 5     Karan   Delhi  138000
# 8    Anjali   Delhi  132000
# 1      Riya   Delhi   72000
# 9     Mohit  Jaipur  119000
# 3     Rahul  Jaipur   91000
# 0      Aman  Jaipur   85000
# 2      Neha  Mumbai  125000
# 10    Pooja  Mumbai   97000
# 6     Sneha  Mumbai   79000
# 4     Priya    Pune  115000
# 7     Vikas    Pune  102000
# 11    Arjun    Pune   68000

# %%
df.sort_values(by="Salary", ascending=False).tail(4)
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8

# %%
df["Sales_Rank"] = df["Sales"].rank(ascending=False)

df
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8
# 1    E102     Riya         HR   Delhi   52000           4   72000     4.2
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5
#
# ...

# %%
df["Salary_Rank"] = df["Salary"].rank(ascending=False) df[["Employee", "Salary", "Salary_Rank"]]
# Out:
#    Employee  Salary  Salary_Rank
# 0      Aman   42000         12.0
# 1      Riya   52000          8.0
# 2      Neha   68000          3.0
# 3     Rahul   47000         10.0
# 4     Priya   61000          5.0
# 5     Karan   75000          1.0
# 6     Sneha   55000          7.0
# 7     Vikas   49000          9.0
# 8    Anjali   72000          2.0
# 9     Mohit   65000          4.0
# 10    Pooja   58000          6.0
# 11    Arjun   45000         11.0

# %%
df["Rating_Rank"] = df["Rating"].rank(ascending=False,method="dense")
df[["Employee", "Rating", "Rating_Rank"]]
# Out:
#    Employee  Rating  Rating_Rank
# 0      Aman     3.8         10.0
# 1      Riya     4.2          6.0
# 2      Neha     4.7          2.0
# 3     Rahul     3.9          9.0
# 4     Priya     4.5          4.0
# 5     Karan     4.8          1.0
# 6     Sneha     4.1          7.0
# 7     Vikas     3.7         11.0
# 8    Anjali     4.6          3.0
# 9     Mohit     4.4          5.0
# 10    Pooja     4.0          8.0
# 11    Arjun     3.5         12.0

# %%
df["Sales_Rank"] = df["Sales"].rank(ascending=False,method="dense")
df.loc[df["Sales_Rank"] <= 3]
# Out:
#   Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 2   E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 5   E106    Karan         IT   Delhi   75000           7  138000     4.8
# 8   E109   Anjali    Finance   Delhi   72000           6  132000     4.6
#
#    Sales_Rank  Salary_Rank  Rating_Rank
# 2         3.0          3.0          2.0
# 5         1.0          1.0          1.0
# 8         2.0          2.0          3.0

# %%
df["Sales_Rank"] = df["Sales"].rank(ascending=False,method="dense")
df.loc[(df["Sales_Rank"] >= 5) &(df["Sales_Rank"] <= 8)]
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
#
#     Sales_Rank  Salary_Rank  Rating_Rank
# 3          8.0         10.0          9.0
# 4          5.0          5.0          4.0
# 7          6.0          9.0         11.0
# 10         7.0          6.0          8.0

# %%
df["Sales_Rank"] = df["Sales"].rank(ascending=False)
df["Salary_Rank"] = df["Salary"].rank(ascending=False)

df.loc[(df["Sales_Rank"] <= 5) | (df["Salary_Rank"] <= 5)]
# Out:
#   Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 2   E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 4   E105    Priya    Finance    Pune   61000           5  115000     4.5
# 5   E106    Karan         IT   Delhi   75000           7  138000     4.8
# 8   E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 9   E110    Mohit         IT  Jaipur   65000           5  119000     4.4
#
#    Sales_Rank  Salary_Rank  Rating_Rank
# 2         3.0          3.0          2.0
# 4         5.0          5.0          4.0
# 5         1.0          1.0          1.0
# 8         2.0          2.0          3.0
# 9         4.0          4.0          5.0

# %%
df = df.set_index("Emp_ID")df.loc["E103":"E108"]
# Out:
#        Employee Department    City  Salary  Experience   Sales  Rating  \
# Emp_ID
# E103       Neha         IT  Mumbai   68000           6  125000     4.7
# E104      Rahul      Sales  Jaipur   47000           3   91000     3.9
# E105      Priya    Finance    Pune   61000           5  115000     4.5
# E106      Karan         IT   Delhi   75000           7  138000     4.8
# E107      Sneha         HR  Mumbai   55000           4   79000     4.1
# E108      Vikas      Sales    Pune   49000           3  102000     3.7
#
#         Sales_Rank  Salary_Rank  Rating_Rank
# Emp_ID
# E103           3.0          3.0          2.0
# E104           8.0         10.0          9.0
# E105           5.0          5.0          4.0
# E106           1.0          1.0          1.0
# E107          10.0          7.0          7.0
# E108           6.0          9.0         11.0

# %%
df.loc[df["Sales"] > 100000,["Employee", "Department", "Salary", "Sales"]]
# Out:
#        Employee Department  Salary   Sales
# Emp_ID
# E103       Neha         IT   68000  125000
# E105      Priya    Finance   61000  115000
# E106      Karan         IT   75000  138000
# E108      Vikas      Sales   49000  102000
# E109     Anjali    Finance   72000  132000
# E110      Mohit         IT   65000  119000

# %%
df.loc[df["Department"] == "Finance",["Employee", "City", "Salary"]]
# Out:
#        Employee   City  Salary
# Emp_ID
# E105      Priya   Pune   61000
# E109     Anjali  Delhi   72000

# %%
df.loc[
    (df["City"].isin(["Jaipur", "Delhi"])) &
    (df["Rating"] >= 4.0)
]
# Out:
#        Employee Department    City  Salary  Experience   Sales  Rating  \
# Emp_ID
# E102       Riya         HR   Delhi   52000           4   72000     4.2
# E106      Karan         IT   Delhi   75000           7  138000     4.8
# E109     Anjali    Finance   Delhi   72000           6  132000     4.6
# E110      Mohit         IT  Jaipur   65000           5  119000     4.4
#
#         Sales_Rank  Salary_Rank  Rating_Rank
# Emp_ID
# E102          11.0          8.0          6.0
# E106           1.0          1.0          1.0
# E109           2.0          2.0          3.0
# E110           4.0          4.0          5.0

# %%
df.loc[
    ["E102", "E105", "E108", "E111"],
    ["Employee", "Department", "Rating"]
]
# Out:
#        Employee Department  Rating
# Emp_ID
# E102       Riya         HR     4.2
# E105      Priya    Finance     4.5
# E108      Vikas      Sales     3.7
# E111      Pooja      Sales     4.0

# %%
df["Performance"] = "Normal"

df.loc[df["Rating"] >= 4.5, "Performance"] = "High"

df
# Out:
#        Employee Department    City  Salary  Experience   Sales  Rating  \
# Emp_ID
# E101       Aman      Sales  Jaipur   42000           2   85000     3.8
# E102       Riya         HR   Delhi   52000           4   72000     4.2
# E103       Neha         IT  Mumbai   68000           6  125000     4.7
# E104      Rahul      Sales  Jaipur   47000           3   91000     3.9
# E105      Priya    Finance    Pune   61000           5  115000     4.5
# E106      Karan         IT   Delhi   75000           7  138000     4.8
# E107      Sneha         HR  Mumbai   55000           4   79000     4.1
# E108      Vikas      Sales    Pune   49000           3  102000     3.7
# E109     Anjali    Finance   Delhi   72000           6  132000     4.6
# E110      Mohit         IT  Jaipur   65000           5  119000     4.4
# E111      Pooja      Sales  Mumbai   58000           4   97000     4.0
# E112      Arjun         HR    Pune   45000           2   68000     3.5
#
# ...

# %%
df = df.reset_index()

# %%
df.iloc[2:7, 1:5]
# Out:
#   Employee Department    City  Salary
# 2     Neha         IT  Mumbai   68000
# 3    Rahul      Sales  Jaipur   47000
# 4    Priya    Finance    Pune   61000
# 5    Karan         IT   Delhi   75000
# 6    Sneha         HR  Mumbai   55000

# %%
df.iloc[-5:, 4:7]
# Out:
#     Salary  Experience   Sales
# 7    49000           3  102000
# 8    72000           6  132000
# 9    65000           5  119000
# 10   58000           4   97000
# 11   45000           2   68000

# %%
df.iloc[::2]
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
#
#     Sales_Rank  Salary_Rank  Rating_Rank Performance
# 0          9.0         12.0         10.0      Normal
# 2          3.0          3.0          2.0        High
# 4          5.0          5.0          4.0        High
# 6         10.0          7.0          7.0      Normal
# 8          2.0          2.0          3.0        High
# 10         7.0          6.0          8.0      Normal

# %%
df.iloc[[1, 4, 7, 10], [1, 3, 6]]
# Out:
#    Employee    City   Sales
# 1      Riya   Delhi   72000
# 4     Priya    Pune  115000
# 7     Vikas    Pune  102000
# 10    Pooja  Mumbai   97000

# %%
df.iloc[:8, -3:]
# Out:
#    Salary_Rank  Rating_Rank Performance
# 0         12.0         10.0      Normal
# 1          8.0          6.0      Normal
# 2          3.0          2.0        High
# 3         10.0          9.0      Normal
# 4          5.0          4.0        High
# 5          1.0          1.0        High
# 6          7.0          7.0      Normal
# 7          9.0         11.0      Normal

# %%
new_df = df.sort_values(by="Sales", ascending=False).reset_index(drop=True)

new_df.iloc[[1, 4, 7]]
# Out:
#   Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 1   E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 4   E105    Priya    Finance    Pune   61000           5  115000     4.5
# 7   E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
#
#    Sales_Rank  Salary_Rank  Rating_Rank Performance
# 1         2.0          2.0          3.0        High
# 4         5.0          5.0          4.0        High
# 7         8.0         10.0          9.0      Normal

# %%
new_df = df.sort_values(
    by=["Department", "Sales"],
    ascending=[True, False]
)

new_df.loc[new_df["Sales"] > 100000]
# Out:
#   Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 8   E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 4   E105    Priya    Finance    Pune   61000           5  115000     4.5
# 5   E106    Karan         IT   Delhi   75000           7  138000     4.8
# 2   E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 9   E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 7   E108    Vikas      Sales    Pune   49000           3  102000     3.7
#
#    Sales_Rank  Salary_Rank  Rating_Rank Performance
# 8         2.0          2.0          3.0        High
# 4         5.0          5.0          4.0        High
# 5         1.0          1.0          1.0        High
# 2         3.0          3.0          2.0        High
# 9         4.0          4.0          5.0      Normal
# 7         6.0          9.0         11.0      Normal

# %%
df["Sales_Rank"] = df["Sales"].rank(ascending=False)
df["Salary_Rank"] = df["Salary"].rank(ascending=False)

df.sort_values(
    by=["Sales_Rank", "Salary_Rank"]
)
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 1    E102     Riya         HR   Delhi   52000           4   72000     4.2
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5
#
# ...

# %%
top3 = (
    df.sort_values(by="Sales", ascending=False)
      .groupby("City")
      .head(3)
)

top3
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 1    E102     Riya         HR   Delhi   52000           4   72000     4.2
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5
#
# ...

# %%
df.sort_values(by="Rating", ascending=False) \
  .iloc[:5, [1, 2, 7, 6]]
# Out:
#   Employee Department  Rating   Sales
# 5    Karan         IT     4.8  138000
# 2     Neha         IT     4.7  125000
# 8   Anjali    Finance     4.6  132000
# 4    Priya    Finance     4.5  115000
# 9    Mohit         IT     4.4  119000

# %%
df["Sales_Rank"] = df["Sales"].rank(
    ascending=False,
    method="dense"
)

df.loc[
    (df["Sales_Rank"] >= 4) &
    (df["Sales_Rank"] <= 8)
]
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating  \
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
#
#     Sales_Rank  Salary_Rank  Rating_Rank Performance
# 3          8.0         10.0          9.0      Normal
# 4          5.0          5.0          4.0        High
# 7          6.0          9.0         11.0      Normal
# 9          4.0          4.0          5.0      Normal
# 10         7.0          6.0          8.0      Normal

# %%
new_df = (
    df.sort_values(by="Salary", ascending=False)
      .set_index("Emp_ID")
)

new_df.loc[["E105", "E106", "E109"]]
# Out:
#        Employee Department   City  Salary  Experience   Sales  Rating  \
# Emp_ID
# E105      Priya    Finance   Pune   61000           5  115000     4.5
# E106      Karan         IT  Delhi   75000           7  138000     4.8
# E109     Anjali    Finance  Delhi   72000           6  132000     4.6
#
#         Sales_Rank  Salary_Rank  Rating_Rank Performance
# Emp_ID
# E105           5.0          5.0          4.0        High
# E106           1.0          1.0          1.0        High
# E109           2.0          2.0          3.0        High

# %%
df["Dense_Rank"] = df["Salary"].rank(
    ascending=False,
    method="dense"
)

df["Min_Rank"] = df["Salary"].rank(
    ascending=False,
    method="min"
)

df[["Employee", "Salary", "Dense_Rank", "Min_Rank"]]
# Out:
#    Employee  Salary  Dense_Rank  Min_Rank
# 0      Aman   42000        12.0      12.0
# 1      Riya   52000         8.0       8.0
# 2      Neha   68000         3.0       3.0
# 3     Rahul   47000        10.0      10.0
# 4     Priya   61000         5.0       5.0
# 5     Karan   75000         1.0       1.0
# 6     Sneha   55000         7.0       7.0
# 7     Vikas   49000         9.0       9.0
# 8    Anjali   72000         2.0       2.0
# 9     Mohit   65000         4.0       4.0
# 10    Pooja   58000         6.0       6.0
# 11    Arjun   45000        11.0      11.0

# %%
result = (
    df[df["Experience"] >= 4]
      .sort_values(by="Sales", ascending=False)
      .iloc[2:6]
)

result[["Employee", "Experience", "Sales", "Rating"]]
# Out:
#    Employee  Experience   Sales  Rating
# 2      Neha           6  125000     4.7
# 9     Mohit           5  119000     4.4
# 4     Priya           5  115000     4.5
# 10    Pooja           4   97000     4.0
